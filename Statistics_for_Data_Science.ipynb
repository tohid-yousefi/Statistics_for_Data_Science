# %% [markdown]
# # Veri Bilimi için İstatistik
#
# 📌 Bu kısımda veri biliminde en sık kullanılan istatistiksel yöntemleri ve mtotlarını inceledim.
#
# * Tek Örneklem T Testi
# * Nonparametrik Tek Örneklem Testi
# * Tek Örneklem Oran Testi
# * İki Örneklem Oran Testi
# * Bağımsız İki Örneklem T Testi(AB Testi)
# * Nonparametrik Bağımsız İki Örneklem T Testi
# * Bağımlı İki Örneklem T Testi(AB Testi)
# * Nonparametrik Bağımlı İki Örneklem T Testi
# * Varyans Analizi
# * Nonparametrik Hipotezi(Varyans Analizi)
# * Korelasyon Analizi
# * Nonparametrik Hipotezi(Korelasyon Analizi)

# %% [markdown]
# # Tek Örneklem T Testi
#
# 📌 Popülasyon ortalaması ile varsayımsal bir değer arasında istatistiksel olarak anlamlı bir farklılık olup olmadığını test etmek için kullanılan parametrik bir testtir.
#
# **Örnek ortalamasına ilişkin test yapmak için kullanılır.**
#
# **Hipotezler:**
#
# <d><i>H</i><sub>0</sub>: <i>μ</i> = <i>50</i></d>
# <d><i>H</i><sub>1</sub>: <i>μ</i> ≠ <i>50</i></d><br><br>
#
# <d><i>H</i><sub>0</sub>: <i>μ</i> <= <i>50</i></d><br>
# <d><i>H</i><sub>1</sub>: <i>μ</i> > <i>50</i></d><br><br>
#
# <d><i>H</i><sub>0</sub>: <i>μ</i> >= <i>50</i></d><br>
# <d><i>H</i><sub>1</sub>: <i>μ</i> < <i>50</i></d><br><br>

# %%
# verimizi
import numpy as np
olcumler = np.array([17, 160, 234, 149, 145, 107, 197, 75, 201, 225, 211, 119, 
              157, 145, 127, 244, 163, 114, 145,  65, 112, 185, 202, 146,
              203, 224, 203, 114, 188, 156, 187, 154, 177, 95, 165, 50, 110, 
              216, 138, 151, 166, 135, 155, 84, 251, 173, 131, 207, 121, 120])

# %% [markdown]
# ## Varsayımlar
#
# Normallik:
# * histogram
# * qqplot
# * shapiro-wilks testi

# %%
# histogram
import pandas as pd
pd.DataFrame(olcumler).plot.hist();

# %%
# qqplot
import pylab
import scipy.stats as stats
stats.probplot(olcumler, dist="norm", plot=pylab)
pylab.show()

# %%
# Shapiro-Wilks Test
from scipy.stats import shapiro
T_istatistigi , p_value = shapiro(olcumler)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05:
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# T istatistiği: 0.9853 , P value değeri: 0.7849
# Veriler Normal Dağılmıştır.

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark yoktur
#
# H1: Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark vardır

# %%
from scipy.stats import shapiro,ttest_1samp
from statsmodels.stats.descriptivestats import sign_test
T_istatistigi , p_value = shapiro(olcumler)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05:
  print("Veriler Normal Dağılmamıştır ve Nonparametrik Tek Örneklem T Testi Uygulanmalıdır.")
  T_istatistigi , p_value = sign_test(olcumler, 170)
  if p_value < 0.05:
    print("Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark vardır. H0 hipotezi reddedilir.")
  else:
    print("Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark yoktur. H0 hipotezi reddedilemez.")
else:
  print("Veriler Normal Dağılmıştır. Tek Örneklem Testi Uygulanabilir.")
  T_istatistigi , p_value = stats.ttest_1samp(olcumler, popmean=170)
  if p_value < 0.05:
    print("Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark vardır. H0 hipotezi reddedilir.")
  else:
    print("Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark yoktur. H0 hipotezi reddedilemez.")
# Out:
# T istatistiği: 0.9853 , P value değeri: 0.7849
# Veriler Normal Dağılmıştır. Tek Örneklem Testi Uygulanabilir.
# Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark vardır. H0 hipotezi reddedilir.

# %% [markdown]
# # Nonparametrik Tek Örneklem Testi
#
# 📌 Tek Örneklem T Testini uyguladığımıza eğer varsayımlar sağlanmadıysa Nonparametrik Tek Örneklem T Testi uygulanır.

# %%
# verimiz
import numpy as np
olcumler = np.random.randint(0,200,50)

# %% [markdown]
# ## Varsayımlar
#
# Normallik:
# * histogram
# * qqplot
# * shapiro-wilks testi
#
# **Not**: Varsayım sağlanmadıysa Nonparametrik Tek Örneklem T Testi uygulanacaktır.

# %%
# histogram
import pandas as pd
pd.DataFrame(olcumler).plot.hist();

# %%
# qqplot
import pylab
import scipy.stats as stats
stats.probplot(olcumler, dist="norm", plot=pylab);

# %%
# Shapiro-Wilks Test
from scipy.stats import shapiro
T_istatistigi , p_value = shapiro(olcumler)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05:
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# T istatistiği: 0.9610 , P value değeri: 0.0983
# Veriler Normal Dağılmıştır.

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark yoktur
#
# H1: Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark vardır

# %%
from scipy.stats import shapiro
from statsmodels.stats.descriptivestats import sign_test
T_istatistigi , p_value = shapiro(olcumler)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05:
  print("Veriler Normal Dağılmamıştır ve Nonparametrik Tek Örneklem T Testi Uygulanmalıdır.")
  T_istatistigi , p_value = sign_test(olcumler, 170)
  if p_value < 0.05:
    print("Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark vardır. H0 hipotezi reddedilir.")
  else:
    print("Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark yoktur. H0 hipotezi reddedilemez.")
else:
  print("Veriler Normal Dağılmıştır. Tek Örneklem Testi Uygulanabilir.")
  T_istatistigi , p_value = stats.ttest_1samp(olcumler, popmean=170)
  if p_value < 0.05:
    print("Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark vardır. H0 hipotezi reddedilir.")
  else:
    print("Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark yoktur. H0 hipotezi reddedilemez.")
# Out:
# T istatistiği: 0.9610 , P value değeri: 0.0983
# Veriler Normal Dağılmıştır. Tek Örneklem Testi Uygulanabilir.
# Örnek dağılımı ile teorik normal dağılım arasında istatistiksel olarak anlamlı bir fark vardır. H0 hipotezi reddedilir.

# %% [markdown]
# # Tek Örneklem Oran Testi
#
# 📌 Oransal bir ifade test edilmek istenildiğinde kullanılır.
#
# H0: p=0.125
#
# H1: p!=0.125

# %%
from statsmodels.stats.proportion import proportions_ztest
count = 40
nobs = 500
value = 0.125
T_istatistigi, p_value = proportions_ztest(count, nobs, value)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05:
  print("H0 hipotezi reddedilir.")
else:
  print("H0 hipotezi reddedilemez.")
# Out:
# T istatistiği: -3.7090 , P value değeri: 0.0002
# H0 hipotezi reddedilir.

# %% [markdown]
# # İki Örneklem Oran Testi
#
#
# 📌 İki oran arasında karşılaştırma yapmak için kullanılır.
#
# H0: Farklılık yoktur.
#
# H1: Farklılık vardır.

# %%
from statsmodels.stats.proportion import proportions_ztest
import numpy as np

basari_sayisi = np.array([300,250])
gozlem_sayisi = np.array([1000,1100])
T_istatistigi, p_value = proportions_ztest(count=basari_sayisi, nobs=gozlem_sayisi)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05:
  print("H0 hipotezi reddedilir.")
else:
  print("H0 hipotezi reddedilemez.")
# Out:
# T istatistiği: 3.7858 , P value değeri: 0.0002
# H0 hipotezi reddedilir.

# %% [markdown]
# # Bağımsız İki Örneklem T Testi(AB Testi)
#
# 📌 İki grup ortalaması arasında karşılaştırma yapılmak istenildiğinde kullanılır.
#
# H0: M1 = M2
#
# H1: M1 != M2

# %%
# Veri Tipi I
import pandas as pd
A = pd.DataFrame([30,27,21,27,29,30,20,20,27,32,35,22,24,23,25,27,23,27,23,
        25,21,18,24,26,33,26,27,28,19,25])

B = pd.DataFrame([37,39,31,31,34,38,30,36,29,28,38,28,37,37,30,32,31,31,27,
        32,33,33,33,31,32,33,26,32,33,29])
A_B = pd.concat([A,B],axis=1)
A_B.columns = ["A","B"]
A_B.head()
# Out:
#     A   B
# 0  30  37
# 1  27  39
# 2  21  31
# 3  27  31
# 4  29  34

# %%
# Veri Tipi II
A = pd.DataFrame([30,27,21,27,29,30,20,20,27,32,35,22,24,23,25,27,23,27,23,
        25,21,18,24,26,33,26,27,28,19,25])

B = pd.DataFrame([37,39,31,31,34,38,30,36,29,28,38,28,37,37,30,32,31,31,27,
        32,33,33,33,31,32,33,26,32,33,29])

# A ve A'nın grubu
Group_A = pd.DataFrame(np.arange(len(A)))
Group_A[:] = "A"
A = pd.concat([A,Group_A], axis = 1)

# B ve B'nin Grubu
Group_B = pd.DataFrame(np.arange(len(B)))
Group_B[:] = "B"
B = pd.concat([B,Group_B], axis = 1)

# Tüm Veri
AB = pd.concat([A,B])
AB.columns = ["gelir","Grup"]
AB.head()
# Out:
#    gelir Grup
# 0     30    A
# 1     27    A
# 2     21    A
# 3     27    A
# 4     29    A

# %%
import seaborn as sns
sns.boxplot(x="Grup", y="gelir", data=AB);

# %% [markdown]
# ## Varsayımlar
#
# 1) Normallik
#
# 2) Varyans Homojenliği

# %%
# normallik varsayımı
# Shapiro-Wilks Test
from scipy.stats import shapiro
A_T_istatistigi , A_p_value = shapiro(A_B.A)
B_T_istatistigi , B_p_value = shapiro(A_B.B)
print("A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
if A_p_value < 0.05 or B_p_value < 0.05:
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# A için: T istatistiği: 0.9789 , P value değeri: 0.7963
# B için: T istatistiği: 0.9561 , P value değeri: 0.2458
# Veriler Normal Dağılmıştır.

# %%
# varyans homojenliği
# levene testi
import scipy.stats as stats
T_istatistigi, p_value = stats.levene(A_B.A,A_B.B)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05 :
  print("Varyanslar Homojen Değildir")
else:
  print("Varyanslar Homojendir")
# Out:
# T istatistiği: 1.1102 , P value değeri: 0.2964
# Varyanslar Homojendir

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: Farklılık yoktur.
#
# H1: Farklılık vardır.

# %%
from scipy.stats import shapiro
import scipy.stats as stats
A_T_istatistigi , A_p_value = shapiro(A_B.A)
B_T_istatistigi , B_p_value = shapiro(A_B.B)
print("A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
if A_p_value < 0.05 or B_p_value < 0.05:
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
  T_istatistigi, p_value = stats.levene(A_B.A,A_B.B)
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05 :
    print("Varyanslar Homojen Değildir")
  else:
    print("Varyanslar Homojendir")
    T_istatistigi , p_value = stats.ttest_ind(A_B["A"],A_B["B"], equal_var=True)
    print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
    if p_value < 0.05:
      print("Farklılık vardır. H0 hipotezi reddedilir.")
    else:
      print("Farklılık yoktur. H0 hiptezi reddedilemez.")
# Out:
# A için: T istatistiği: 0.9789 , P value değeri: 0.7963
# B için: T istatistiği: 0.9561 , P value değeri: 0.2458
# Veriler Normal Dağılmıştır.
# T istatistiği: 1.1102 , P value değeri: 0.2964
# Varyanslar Homojendir
# T istatistiği: -7.0287 , P value değeri: 0.0000
# Farklılık vardır. H0 hipotezi reddedilir.

# %% [markdown]
# # Nonparametrik Bağımsız İki Örneklem T Testi
#
# 📌 Bağımsız İki Örneklem T Testini uyguladığımıza eğer varsayımlar sağlanmadıysa Nonparametrik Bağımsız İki Örneklem T Testi uygulanır.

# %%
# Veri Tipi I
import pandas as pd
import numpy as np
A = pd.DataFrame(pd.DataFrame(np.random.normal(0,200,50)))
B = pd.DataFrame(pd.DataFrame(np.random.randint(0,200,50)))
A_B = pd.concat([A,B],axis=1)
A_B.columns = ["A","B"]
A_B.head()
# Out:
#             A    B
# 0  -72.728125  197
# 1   57.843153  162
# 2 -103.580739   62
# 3 -122.926495  145
# 4   23.624211   81

# %%
# Veri Tipi II
# A ve A'nın grubu
Group_A = pd.DataFrame(np.arange(len(A)))
Group_A[:] = "A"
A = pd.concat([A,Group_A], axis = 1)

# B ve B'nin Grubu
Group_B = pd.DataFrame(np.arange(len(B)))
Group_B[:] = "B"
B = pd.concat([B,Group_B], axis = 1)

# Tüm Veri
AB = pd.concat([A,B])
AB.columns = ["gelir","Grup"]
AB.head()
# Out:
#         gelir Grup
# 0  -72.728125    A
# 1   57.843153    A
# 2 -103.580739    A
# 3 -122.926495    A
# 4   23.624211    A

# %%
import seaborn as sns
sns.boxplot(x="Grup", y="gelir", data=AB);

# %% [markdown]
# ## Varsayımlar
#
# 1) Normallik Testi Sağlanmamalı
#
# 2) Varyanslar Homojen Olmamalı
#
# **Not**: Yukarıdaki şartlar projeye göre hafifletilebilir.

# %%
# normallik varsayımı
# Shapiro-Wilks Test
from scipy.stats import shapiro
A_T_istatistigi , A_p_value = shapiro(A_B.A)
B_T_istatistigi , B_p_value = shapiro(A_B.B)
print("A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
if (A_p_value < 0.05) or (B_p_value < 0.05):
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# A için: T istatistiği: 0.9850 , P value değeri: 0.7702
# B için: T istatistiği: 0.9436 , P value değeri: 0.0188
# Veriler Normal Dağılmamıştır.

# %%
# varyans homojenliği
# levene testi
import scipy.stats as stats
T_istatistigi, p_value = stats.levene(A_B.A,A_B.B)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05 :
  print("Varyanslar Homojen Değildir")
else:
  print("Varyanslar Homojendir")
# Out:
# T istatistiği: 33.7626 , P value değeri: 0.0000
# Varyanslar Homojen Değildir

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: Farklılık yoktur.
#
# H1: Farklılık vardır.

# %%
from scipy.stats import shapiro
import scipy.stats as stats
A_T_istatistigi , A_p_value = shapiro(A_B.A)
B_T_istatistigi , B_p_value = shapiro(A_B.B)
print("Normallik = A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Normallik = B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
T_istatistigi, p_value = stats.levene(A_B.A,A_B.B)
print("Varyans Homojenliği = T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if (A_p_value < 0.05 or B_p_value < 0.05) or (p_value < 0.05):
  print("Varsayımlar Sağlanmıyor")
  T_istatistigi, p_value = stats.mannwhitneyu(A_B["A"],A_B["B"])
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05:
    print("Farklılık vardır. H0 hipotezi reddedilir.")
  else:
    print("Farklılık yoktur. H0 hiptezi reddedilemez.")
else:
  print("Varsayımlar Sağlanıyor")
  T_istatistigi , p_value = stats.ttest_ind(A_B["A"],A_B["B"], equal_var=True)
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05:
    print("Farklılık vardır. H0 hipotezi reddedilir.")
  else:
    print("Farklılık yoktur. H0 hiptezi reddedilemez.")
# Out:
# Normallik = A için: T istatistiği: 0.9850 , P value değeri: 0.7702
# Normallik = B için: T istatistiği: 0.9436 , P value değeri: 0.0188
# Varyans Homojenliği = T istatistiği: 33.7626 , P value değeri: 0.0000
# Varsayımlar Sağlanmıyor
# T istatistiği: 603.0000 , P value değeri: 0.0000
# Farklılık vardır. H0 hipotezi reddedilir.

# %% [markdown]
# # Bağımlı İki Örneklem T Testi(AB Testi)
#
# 📌 Bağımlı İki grup ortalaması arasında karşılaştırma yapılmak istenildiğinde kullanılır.
#
# H0: M1 = M2
#
# H1: M1 != M2

# %%
# Veri Tipi I
import numpy as np
import pandas as pd
oncesi = pd.DataFrame([123,119,119,116,123,123,121,120,117,118,121,121,123,119,
            121,118,124,121,125,115,115,119,118,121,117,117,120,120,
            121,117,118,117,123,118,124,121,115,118,125,115])

sonrasi = pd.DataFrame([118,127,122,132,129,123,129,132,128,130,128,138,140,130,
             134,134,124,140,134,129,129,138,134,124,122,126,133,127,
             130,130,130,132,117,130,125,129,133,120,127,123])
A_B = pd.concat([oncesi,sonrasi],axis=1)
A_B.columns = ["Oncesi","Sonrasi"]
A_B.head()
# Out:
#    Oncesi  Sonrasi
# 0     123      118
# 1     119      127
# 2     119      122
# 3     116      132
# 4     123      129

# %%
# Veri Tipi II
oncesi = pd.DataFrame([123,119,119,116,123,123,121,120,117,118,121,121,123,119,
            121,118,124,121,125,115,115,119,118,121,117,117,120,120,
            121,117,118,117,123,118,124,121,115,118,125,115])

sonrasi = pd.DataFrame([118,127,122,132,129,123,129,132,128,130,128,138,140,130,
             134,134,124,140,134,129,129,138,134,124,122,126,133,127,
             130,130,130,132,117,130,125,129,133,120,127,123])

# A ve A'nın grubu
Grup_Oncesi = pd.DataFrame(np.arange(len(oncesi)))
Grup_Oncesi[:] = "ONCESI"
A = pd.concat([oncesi,Grup_Oncesi],axis=1)

# B ve B'nin Grubu
Grup_Sonrasi = pd.DataFrame(np.arange(len(sonrasi)))
Grup_Sonrasi[:] = "SONRASI"
B = pd.concat([sonrasi,Grup_Sonrasi],axis=1)

# Tüm Veri
AB = pd.concat([A,B])
AB.columns = ["PERFORMANS","ONCESI_SONRASI"]
AB.head()
# Out:
#    PERFORMANS ONCESI_SONRASI
# 0         123         ONCESI
# 1         119         ONCESI
# 2         119         ONCESI
# 3         116         ONCESI
# 4         123         ONCESI

# %%
import seaborn as sns
sns.boxplot(x="ONCESI_SONRASI", y="PERFORMANS", data=AB);

# %% [markdown]
# ## Varsayımlar
#
# 1) Normallik
#
# 2) Varyans Homojenliği

# %%
# normallik varsayımı
# Shapiro-Wilks Test
from scipy.stats import shapiro
A_T_istatistigi , A_p_value = shapiro(A_B.Oncesi)
B_T_istatistigi , B_p_value = shapiro(A_B.Sonrasi)
print("Oncesi için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Sonrasi için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
if (A_p_value < 0.05) or (B_p_value < 0.05):
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# Oncesi için: T istatistiği: 0.9544 , P value değeri: 0.1072
# Sonrasi için: T istatistiği: 0.9780 , P value değeri: 0.6159
# Veriler Normal Dağılmıştır.

# %%
# varyans homojenliği
# levene testi
import scipy.stats as stats
T_istatistigi, p_value = stats.levene(A_B.Oncesi,A_B.Sonrasi)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05 :
  print("Varyanslar Homojen Değildir")
else:
  print("Varyanslar Homojendir")
# Out:
# T istatistiği: 8.3130 , P value değeri: 0.0051
# Varyanslar Homojen Değildir

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: Farklılık yoktur.
#
# H1: Farklılık vardır.

# %%
from scipy.stats import shapiro
import scipy.stats as stats
A_T_istatistigi , A_p_value = shapiro(A_B.Oncesi)
B_T_istatistigi , B_p_value = shapiro(A_B.Sonrasi)
print("Oncesi için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Sonrasi için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
if A_p_value < 0.05 or B_p_value < 0.05:
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
  T_istatistigi, p_value = stats.levene(A_B.Oncesi,A_B.Sonrasi)
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05 :
    print("Varyanslar Homojen Değildir")
  else:
    print("Varyanslar Homojendir")
    T_istatistigi , p_value = stats.ttest_rel(A_B.Oncesi, A_B.Sonrasi)
    print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
    if p_value < 0.05:
      print("Farklılık vardır. H0 hipotezi reddedilir.")
    else:
      print("Farklılık yoktur. H0 hiptezi reddedilemez.")
# Out:
# Oncesi için: T istatistiği: 0.9544 , P value değeri: 0.1072
# Sonrasi için: T istatistiği: 0.9780 , P value değeri: 0.6159
# Veriler Normal Dağılmıştır.
# T istatistiği: 8.3130 , P value değeri: 0.0051
# Varyanslar Homojen Değildir

# %% [markdown]
# # Nonparametrik Bağımlı İki Örneklem T Testi
#
# 📌 Bağımlı İki Örneklem T Testini uyguladığımızda eğer varsayımlar sağlanmadıysa Nonparametrik Bağımlı İki Örneklem T Testi uygulanır.

# %%
# Veri Tipi I
import numpy as np
import pandas as pd
oncesi = pd.DataFrame(np.random.randint(0,200,50))

sonrasi = pd.DataFrame(np.random.randint(0,200,50))
A_B = pd.concat([oncesi,sonrasi],axis=1)
A_B.columns = ["Oncesi","Sonrasi"]
A_B.head()
# Out:
#    Oncesi  Sonrasi
# 0     129      143
# 1      52      158
# 2      82      118
# 3     129       98
# 4      35      160

# %%
# Veri Tipi II
# A ve A'nın grubu
Grup_Oncesi = pd.DataFrame(np.arange(len(oncesi)))
Grup_Oncesi[:] = "ONCESI"
A = pd.concat([oncesi,Grup_Oncesi],axis=1)

# B ve B'nin Grubu
Grup_Sonrasi = pd.DataFrame(np.arange(len(sonrasi)))
Grup_Sonrasi[:] = "SONRASI"
B = pd.concat([sonrasi,Grup_Sonrasi],axis=1)

# Tüm Veri
AB = pd.concat([A,B])
AB.columns = ["PERFORMANS","ONCESI_SONRASI"]
AB.head()
# Out:
#    PERFORMANS ONCESI_SONRASI
# 0         129         ONCESI
# 1          52         ONCESI
# 2          82         ONCESI
# 3         129         ONCESI
# 4          35         ONCESI

# %%
import seaborn as sns
sns.boxplot(x="ONCESI_SONRASI", y="PERFORMANS", data=AB);

# %% [markdown]
# ## Varsayımlar
#
# 1) Normallik Testi Sağlanmamalı
#
# 2) Varyanslar Homojen Olmamalı
#
# **Not**: Yukarıdaki şartlar projeye göre hafifletilebilir.

# %%
# normallik varsayımı
# Shapiro-Wilks Test
from scipy.stats import shapiro
A_T_istatistigi , A_p_value = shapiro(A_B.Oncesi)
B_T_istatistigi , B_p_value = shapiro(A_B.Sonrasi)
print("Oncesi için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Sonrasi için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
if (A_p_value < 0.05) or (B_p_value < 0.05):
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# Oncesi için: T istatistiği: 0.9575 , P value değeri: 0.0697
# Sonrasi için: T istatistiği: 0.9509 , P value değeri: 0.0373
# Veriler Normal Dağılmamıştır.

# %%
# varyans homojenliği
# levene testi
import scipy.stats as stats
T_istatistigi, p_value = stats.levene(A_B.Oncesi,A_B.Sonrasi)
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05 :
  print("Varyanslar Homojen Değildir")
else:
  print("Varyanslar Homojendir")
# Out:
# T istatistiği: 1.2298 , P value değeri: 0.2702
# Varyanslar Homojendir

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: Farklılık yoktur.
#
# H1: Farklılık vardır.

# %%
from scipy.stats import shapiro
import scipy.stats as stats
A_T_istatistigi , A_p_value = shapiro(A_B.Oncesi)
B_T_istatistigi , B_p_value = shapiro(A_B.Sonrasi)
print("Normallik = Oncesi için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Normallik = Sonrasi için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
T_istatistigi, p_value = stats.levene(A_B.Oncesi,A_B.Sonrasi)
print("Varyans Homojenliği = T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if (A_p_value < 0.05 or B_p_value < 0.05) or (p_value < 0.05):
  print("Varsayımlar Sağlanmıyor")
  T_istatistigi, p_value = stats.wilcoxon(A_B.Oncesi,A_B.Sonrasi)
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05:
    print("Farklılık vardır. H0 hipotezi reddedilir.")
  else:
    print("Farklılık yoktur. H0 hiptezi reddedilemez.")
else:
  print("Varsayımlar Sağlanıyor")
  T_istatistigi , p_value = stats.ttest_rel(A_B.Oncesi, A_B.Sonrasi)
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05:
    print("Farklılık vardır. H0 hipotezi reddedilir.")
  else:
    print("Farklılık yoktur. H0 hiptezi reddedilemez.")
# Out:
# Normallik = Oncesi için: T istatistiği: 0.9575 , P value değeri: 0.0697
# Normallik = Sonrasi için: T istatistiği: 0.9509 , P value değeri: 0.0373
# Varyans Homojenliği = T istatistiği: 1.2298 , P value değeri: 0.2702
# Varsayımlar Sağlanmıyor
# T istatistiği: 578.5000 , P value değeri: 0.7352
# Farklılık yoktur. H0 hiptezi reddedilemez.

# %% [markdown]
# # Varyans Analizi
#
# 📌 İki ya da daha fazla grup ortalaması arasında istatistiksel olarak analamlı farklılık olup olmadığını öğrenilmek istenildiğinde kullanılır.

# %%
# verimiz
A = pd.DataFrame([28,33,30,29,28,29,27,31,30,32,28,33,25,29,27,31,31,30,31,34,30,32,31,34,28,32,31,28,33,29])

B = pd.DataFrame([31,32,30,30,33,32,34,27,36,30,31,30,38,29,30,34,34,31,35,35,33,30,28,29,26,37,31,28,34,33])

C = pd.DataFrame([40,33,38,41,42,43,38,35,39,39,36,34,35,40,38,36,39,36,33,35,38,35,40,40,39,38,38,43,40,42])

ABC = pd.concat([A,B,C],axis = 1)
ABC.columns = ["Grup_A","Grup_B","Grup_C"]
ABC.head()
# Out:
#    Grup_A  Grup_B  Grup_C
# 0      28      31      40
# 1      33      32      33
# 2      30      30      38
# 3      29      30      41
# 4      28      33      42

# %% [markdown]
# ## Varsayımlar
#
# 1) Grupların Bağımsızlığı
#
# 2) Normallik
#
# 3) Varyans Homojenliği

# %%
# normallik varsayımı
# Shapiro-Wilks Test
from scipy.stats import shapiro
A_T_istatistigi , A_p_value = shapiro(ABC.Grup_A)
B_T_istatistigi , B_p_value = shapiro(ABC.Grup_B)
C_T_istatistigi , C_p_value = shapiro(ABC.Grup_C)
print("Grup_A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Grup_B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
print("Grup_C için: T istatistiği: %.4f , P value değeri: %.4f" %(C_T_istatistigi, C_p_value))
if (A_p_value < 0.05) or (B_p_value < 0.05) or (C_p_value < 0.05):
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# Grup_A için: T istatistiği: 0.9697 , P value değeri: 0.5322
# Grup_B için: T istatistiği: 0.9790 , P value değeri: 0.7980
# Grup_C için: T istatistiği: 0.9579 , P value değeri: 0.2738
# Veriler Normal Dağılmıştır.

# %%
# varyans homojenliği
# levene testi
import scipy.stats as stats
T_istatistigi, p_value = stats.levene(ABC["Grup_A"], ABC["Grup_B"],ABC["Grup_C"])
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05 :
  print("Varyanslar Homojen Değildir")
else:
  print("Varyanslar Homojendir")
# Out:
# T istatistiği: 1.0267 , P value değeri: 0.3625
# Varyanslar Homojendir

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: M1 = M2 = M3 (Grup ortalamaları arasında anlamlı bir farklılık yoktur.)
#
# H1: (Grup ortalamaları arasında anlamlı bir farklılık vardır.)

# %%
from scipy.stats import shapiro, f_oneway
import scipy.stats as stats
A_T_istatistigi , A_p_value = shapiro(ABC.Grup_A)
B_T_istatistigi , B_p_value = shapiro(ABC.Grup_B)
C_T_istatistigi , C_p_value = shapiro(ABC.Grup_C)
print("Grup_A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Grup_B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
print("Grup_C için: T istatistiği: %.4f , P value değeri: %.4f" %(C_T_istatistigi, C_p_value))
if (A_p_value < 0.05) or (B_p_value < 0.05) or (C_p_value < 0.05):
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
  T_istatistigi, p_value = stats.levene(ABC["Grup_A"], ABC["Grup_B"],ABC["Grup_C"])
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05 :
    print("Varyanslar Homojen Değildir")
  else:
    print("Varyanslar Homojendir")
    T_istatistigi, p_value = f_oneway(ABC["Grup_A"], ABC["Grup_B"], ABC["Grup_C"])
    print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
    if p_value < 0.05:
      print("Farklılık vardır. H0 hipotezi reddedilir.")
    else:
      print("Farklılık yoktur. H0 hiptezi reddedilemez.")
# Out:
# Grup_A için: T istatistiği: 0.9697 , P value değeri: 0.5322
# Grup_B için: T istatistiği: 0.9790 , P value değeri: 0.7980
# Grup_C için: T istatistiği: 0.9579 , P value değeri: 0.2738
# Veriler Normal Dağılmıştır.
# T istatistiği: 1.0267 , P value değeri: 0.3625
# Varyanslar Homojendir
# T istatistiği: 74.6928 , P value değeri: 0.0000
# Farklılık vardır. H0 hipotezi reddedilir.

# %% [markdown]
# # Nonparametrik Hipotezi(Varyans Analizi)
#
# 📌 Varyans analizi uyguladığımızda eğer varsayımlar sağlanmadıysa Nonparametrik Varyans Analizi uygulanır.

# %%
# verimiz
import numpy as np
import pandas as pd

A = pd.DataFrame(np.random.randint(0,200,50))

B = pd.DataFrame(np.random.randint(0,200,50))
C = pd.DataFrame(np.random.randint(0,200,50))

ABC = pd.concat([A,B,C],axis = 1)
ABC.columns = ["Grup_A","Grup_B","Grup_C"]
ABC.head()
# Out:
#    Grup_A  Grup_B  Grup_C
# 0      72     100     144
# 1     133      34      72
# 2     185      97     101
# 3       1      17       5
# 4     129      64     115

# %% [markdown]
# ## Varsayımlar
#
# 1) Grupların Bağımlı Olmalı
#
# 2) Normallik Testi Sağlanmamalı
#
# 3) Varyanslar Homojen Olmamalı
#
# **Not**: Yukarıdaki şartlar projeye göre hafifletilebilir.

# %%
# normallik varsayımı
# Shapiro-Wilks Test
from scipy.stats import shapiro
A_T_istatistigi , A_p_value = shapiro(ABC.Grup_A)
B_T_istatistigi , B_p_value = shapiro(ABC.Grup_B)
C_T_istatistigi , C_p_value = shapiro(ABC.Grup_C)
print("Grup_A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Grup_B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
print("Grup_C için: T istatistiği: %.4f , P value değeri: %.4f" %(C_T_istatistigi, C_p_value))
if (A_p_value < 0.05) or (B_p_value < 0.05) or (C_p_value < 0.05):
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# Grup_A için: T istatistiği: 0.9534 , P value değeri: 0.0469
# Grup_B için: T istatistiği: 0.9532 , P value değeri: 0.0463
# Grup_C için: T istatistiği: 0.9411 , P value değeri: 0.0150
# Veriler Normal Dağılmamıştır.

# %%
# varyans homojenliği
# levene testi
import scipy.stats as stats
T_istatistigi, p_value = stats.levene(ABC["Grup_A"], ABC["Grup_B"],ABC["Grup_C"])
print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if p_value < 0.05 :
  print("Varyanslar Homojen Değildir")
else:
  print("Varyanslar Homojendir")
# Out:
# T istatistiği: 0.5566 , P value değeri: 0.5744
# Varyanslar Homojendir

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: Farklılık yoktur.
#
# H1: Farklılık vardır.

# %%
from scipy.stats import shapiro, kruskal
import scipy.stats as stats
A_T_istatistigi , A_p_value = shapiro(ABC.Grup_A)
B_T_istatistigi , B_p_value = shapiro(ABC.Grup_B)
C_T_istatistigi , C_p_value = shapiro(ABC.Grup_C)
print("Normallik = Grup_A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Normallik = Grup_B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
print("Normallik = Grup_C için: T istatistiği: %.4f , P value değeri: %.4f" %(C_T_istatistigi, C_p_value))
T_istatistigi, p_value = stats.levene(ABC["Grup_A"], ABC["Grup_B"],ABC["Grup_C"])
print("Varyans Homojenliği = T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
if (A_p_value < 0.05 or B_p_value < 0.05) or (p_value < 0.05):
  print("Varsayımlar Sağlanmıyor")
  T_istatistigi, p_value = kruskal(ABC["Grup_A"], ABC["Grup_B"], ABC["Grup_C"])
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05:
    print("Farklılık vardır. H0 hipotezi reddedilir.")
  else:
    print("Farklılık yoktur. H0 hiptezi reddedilemez.")
else:
  print("Varsayımlar Sağlanıyor")
  T_istatistigi, p_value = f_oneway(ABC["Grup_A"], ABC["Grup_B"], ABC["Grup_C"])
  print("T istatistiği: %.4f , P value değeri: %.4f" %(T_istatistigi, p_value))
  if p_value < 0.05:
    print("Farklılık vardır. H0 hipotezi reddedilir.")
  else:
    print("Farklılık yoktur. H0 hiptezi reddedilemez.")
# Out:
# Normallik = Grup_A için: T istatistiği: 0.9534 , P value değeri: 0.0469
# Normallik = Grup_B için: T istatistiği: 0.9532 , P value değeri: 0.0463
# Normallik = Grup_C için: T istatistiği: 0.9411 , P value değeri: 0.0150
# Varyans Homojenliği = T istatistiği: 0.5566 , P value değeri: 0.5744
# Varsayımlar Sağlanmıyor
# T istatistiği: 0.7935 , P value değeri: 0.6725
# Farklılık yoktur. H0 hiptezi reddedilemez.

# %% [markdown]
# # Korelasyon Analizi
#
# 📌 Değişkenler arasındaki ilişki, bu ilişkinin yönü ve şiddeti ile ilgili bilgiler sağlayan istatistiksel bir yöntemdir.

# %% [markdown]
# Bahşiş veri seti:
#
# total_bill: yemeğin toplam fiyatı (**bahşiş ve vergi dahil**)
#
# tip: bahşiş
#
# sex: ücreti ödeyen kişinin cinsiyeti (0=male, 1=female)
#
# smoker: grupta sigara içen var mı? (0=No, 1=Yes)
#
# day: gün (3=Thur, 4=Fri, 5=Sat, 6=Sun)
#
# time: ne zaman? (0=Day, 1=Night)
#
# size: grupta kaç kişi var?

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy();
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["total_bill"] = df["total_bill"] - df["tip"]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       15.98  1.01  Female     No  Sun  Dinner     2
# 1        8.68  1.66    Male     No  Sun  Dinner     3
# 2       17.51  3.50    Male     No  Sun  Dinner     3
# 3       20.37  3.31    Male     No  Sun  Dinner     2
# 4       20.98  3.61  Female     No  Sun  Dinner     4

# %%
df.plot.scatter("tip","total_bill");

# %% [markdown]
# ## Varsayımlar
#
# 1) Normallik
#
# **Not**: Varsayım sağlanıyorsa Pearson Korelasyon Katsayısı, eğer sağlanmıyorsa Spearman Korelasyon Katsayısı yada Kendalltau Korelasyon Katsayısı kullanılır.

# %%
# normallik varsayımı
# Shapiro-Wilks Test
from scipy.stats import shapiro
A_T_istatistigi , A_p_value = shapiro(df["tip"])
B_T_istatistigi , B_p_value = shapiro(df["total_bill"])
print("Grup_A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Grup_B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
if (A_p_value < 0.05) or (B_p_value < 0.05):
  print("Veriler Normal Dağılmamıştır.")
else:
  print("Veriler Normal Dağılmıştır.")
# Out:
# Grup_A için: T istatistiği: 0.8978 , P value değeri: 0.0000
# Grup_B için: T istatistiği: 0.9136 , P value değeri: 0.0000
# Veriler Normal Dağılmamıştır.

# %% [markdown]
# ### Hipotez Testinin Uygulanması
#
# H0: Değişkenler arasında anlamlı bir ilişki yoktur.
#
# H1: Değişkenler arasında anlamlı bir ilişki vardır.

# %%
from scipy.stats.stats import pearsonr
p_value = df["tip"].corr(df["total_bill"],method="pearson")
print("Pearson Korelasyon Katsayısı: %.4f" %(p_value))
korelasyon_katsayisi, p_value = pearsonr(df["tip"],df["total_bill"])
print("korelasyon katsayısı: %.4f , P value değeri: %.4f" %(korelasyon_katsayisi, p_value))
if p_value < 0.05:
  print("Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.")
else:
  print("Anlamlı bir ilişki yoktur. H0 hiptezi reddedilemez.")
# Out:
# Pearson Korelasyon Katsayısı: 0.5767
# korelasyon katsayısı: 0.5767 , P value değeri: 0.0000
# Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.

# %%
p_value = df["tip"].corr(df["total_bill"],method="spearman")
print("Spearman Korelasyon Katsayısı: %.4f" %(p_value))
korelasyon_katsayisi, p_value = stats.spearmanr(df["tip"],df["total_bill"])
korelasyon_katsayisi, p_value = stats.kenadlltau(df["tip"],df["total_bill"])
print("korelasyon katsayısı: %.4f , P value değeri: %.4f" %(korelasyon_katsayisi, p_value))
if p_value < 0.05:
  print("Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.")
else:
  print("Anlamlı bir ilişki yoktur. H0 hiptezi reddedilemez.")
# Out:
# Spearman Korelasyon Katsayısı: 0.5937
# korelasyon katsayısı: 0.5937 , P value değeri: 0.0000
# Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.

# %%
korelasyon_katsayisi, p_value = stats.kendalltau(df["tip"],df["total_bill"])
print("korelasyon katsayısı: %.4f , P value değeri: %.4f" %(korelasyon_katsayisi, p_value))
if p_value < 0.05:
  print("Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.")
else:
  print("Anlamlı bir ilişki yoktur. H0 hiptezi reddedilemez.")
# Out:
# korelasyon katsayısı: 0.4401 , P value değeri: 0.0000
# Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.

# %% [markdown]
# # Nonparametrik Hipotezi(Korelasyon Analizi)
#
# 📌 Korelasyon analizi uyguladığımızda eğer varsayımlar sağlanmadıysa Nonparametrik Korelasyon Analizi uygulanır.

# %%
from scipy.stats import shapiro, stats
from scipy.stats.stats import pearsonr 
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy();
df["total_bill"] = df["total_bill"] - df["tip"]

A_T_istatistigi , A_p_value = shapiro(df["tip"])
B_T_istatistigi , B_p_value = shapiro(df["total_bill"])
print("Normallik = Grup_A için: T istatistiği: %.4f , P value değeri: %.4f" %(A_T_istatistigi, A_p_value))
print("Normallik = Grup_B için: T istatistiği: %.4f , P value değeri: %.4f" %(B_T_istatistigi, B_p_value))
if (A_p_value < 0.05) or (B_p_value < 0.05):
  print("Varsayım Sağlanmıyor.")
  p_value = df["tip"].corr(df["total_bill"],method="spearman")
  print("Spearman Korelasyon Katsayısı: %.4f" %(p_value))
  korelasyon_katsayisi, p_value = stats.spearmanr(df["tip"],df["total_bill"])
  #korelasyon_katsayisi, p_value = stats.kendalltau(df["tip"],df["total_bill"])
  print("korelasyon katsayısı: %.4f , P value değeri: %.4f" %(korelasyon_katsayisi, p_value))
  if p_value < 0.05:
    print("Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.")
  else:
    print("Anlamlı bir ilişki yoktur. H0 hiptezi reddedilemez.")
else:
  print("Varsayım Sağlanıyor")
  p_value = df["tip"].corr(df["total_bill"],method="pearson")
  print("Pearson Korelasyon Katsayısı: %.4f" %(p_value))
  korelasyon_katsayisi, p_value = pearsonr(df["tip"],df["total_bill"])
  print("korelasyon katsayısı: %.4f , P value değeri: %.4f" %(korelasyon_katsayisi, p_value))
  if p_value < 0.05:
    print("Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.")
  else:
    print("Anlamlı bir ilişki yoktur. H0 hiptezi reddedilemez.")
# Out:
# Normallik = Grup_A için: T istatistiği: 0.8978 , P value değeri: 0.0000
# Normallik = Grup_B için: T istatistiği: 0.9136 , P value değeri: 0.0000
# Varsayım Sağlanmıyor.
# Spearman Korelasyon Katsayısı: 0.5937
# korelasyon katsayısı: 0.5937 , P value değeri: 0.0000
# Anlamlı bir ilişki vardır. H0 hipotezi reddedilir.
